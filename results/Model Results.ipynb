# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
t = np.arange(0.0, 2.0, 0.01)
s = 1 + np.sin(2*np.pi*t)

# %%
plt.plot(t, s)

plt.xlabel('time (s)')
plt.ylabel('voltage (mV)')
plt.title('About as simple as it gets, folks')
plt.grid(True)
plt.savefig("test.png")
plt.show()

# %%
"""
# OLD VALUES
max_length = np.array ([5, 10, 15, 20, 25, 30, 35, 40])
length_acc = np.array ([0.757117, 0.818823, 0.834410, 0.836151, 0.837453, 0.840005, 0.839819, 0.841595])
length_f1 = np.array ([0.652066, 0.756395, 0.778605, 0.778331, 0.790043, 0.795169, 0.796153, 0.795941])
"""
max_length = np.array ([5, 10, 20, 30, 40])
length_acc = np.array ([0.783405464, 0.842777928, 0.862067217, 0.863149175, 0.862117933])
length_f1 = np.array ([0.70003746, 0.777405457, 0.808971928, 0.810346039, 0.814010763])

# %%
plt.plot (max_length, length_acc, 'ro-', label='accuracy')
plt.plot ( max_length, length_f1, 'bo-', label='f1')
plt.xlabel ('standardized length')
plt.title ('Standardized Sentence Length Hyperparameter Search')
plt.legend (loc=4)
plt.grid ()
plt.savefig("max_length.png", bbox_inches="tight", dpi=500, transparent=True)

# %%
"""
# OLD VALUES
hidden_acc_raw = [(50, 0.831501893427103), (100, 0.8369962131457939), (150, 0.8418819312956451), (200, 0.8438767919935083), (250, 0.8498951852853666), (300, 0.8489653773329727), (350, 0.8487794157424939)]
hidden_f1_raw = [(50, 0.7857060730793112), (100, 0.7936397075941705), (150, 0.7985156487035265), (200, 0.7982414673347831), (250, 0.8047374387920014), (300, 0.8036523079888215), (350, 0.8090401811771848)]"""

# %%
"""hidden_sizes = np.array([x[0] for x in hidden_acc_raw])
hidden_acc = np.array([x[1] for x in hidden_acc_raw])
hidden_f1 = np.array([x[1] for x in hidden_f1_raw])"""

hidden_sizes = np.array ([100, 150, 200, 250, 300])
hidden_acc = np.array ([0.857976062, 0.857925345, 0.859024209, 0.863149175, 0.865583581])
hidden_f1 = np.array ([0.803747051, 0.807415555, 0.811296418, 0.810346039, 0.8161661])

# %%
plt.plot (hidden_sizes, hidden_acc, 'ro-', label='accuracy')
plt.plot (hidden_sizes, hidden_f1, 'bo-', label='f1')
plt.xlabel ('hidden size')
plt.title ('Hidden Layer Size Hyperparameter Search')
plt.legend (loc=5)
plt.grid ()
plt.savefig("hidden_size.png", bbox_inches="tight", dpi=500, transparent=True)
